# %%
import pandas as pd

# %%
path= "/content/concrete_data.csv"
data = pd.read_csv(path)
data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
X = data.iloc[:, :8].values
Y = data.iloc[:, 8].values.reshape(-1,1)

# %%
X
# Out:
# array([[ 540. ,    0. ,    0. , ..., 1040. ,  676. ,   28. ],
#        [ 540. ,    0. ,    0. , ..., 1055. ,  676. ,   28. ],
#        [ 332.5,  142.5,    0. , ...,  932. ,  594. ,  270. ],
#        ...,
#        [ 148.5,  139.4,  108.6, ...,  892.4,  780. ,   28. ],
#        [ 159.1,  186.7,    0. , ...,  989.6,  788.9,   28. ],
#        [ 260.9,  100.5,   78.3, ...,  864.5,  761.5,   28. ]])

# %%
X.shape
# Out:
# (1030, 8)

# %%
Y.shape
# Out:
# (1030, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = .2, random_state=2021)

# %%
from xgboost import XGBRegressor
xgb_model = XGBRegressor(random_state = 2021)

# %%
# make a dictionary of hyperparameter values to search
search_space = {
    "n_estimators" : [100, 200, 500],
    "max_depth" : [3, 6, 9],
    "gamma" : [0.01, 0.1],
    "learning_rate" : [0.001, 0.01, 0.1, 1]
}

# %%
from sklearn.model_selection import GridSearchCV
# make a GridSearchCV object
GS = GridSearchCV(estimator = xgb_model,
                  param_grid = search_space,
                  scoring = ["r2", "neg_root_mean_squared_error"], #sklearn.metrics.SCORERS.keys()
                  refit = "r2",
                  cv = 5,
                  verbose = 4)

# %%
GS.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-15.323) r2: (test=0.112) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-15.412) r2: (test=0.103) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-16.069) r2: (test=0.119) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-15.383) r2: (test=0.106) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-16.454) r2: (test=0.108) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-14.442) r2: (test=0.211) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-14.597) r2: (test=0.195) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-15.144) r2: (test=0.217) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-14.577) r2: (test=0.198) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-15.529) r2: (test=0.205) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-12.247) r2: (test=0.433) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-12.620) r2: (test=0.398) total time=   0.3s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-12.992) r2: (test=0.424) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-12.589) r2: (test=0.402) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-13.347) r2: (test=0.413) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-15.070) r2: (test=0.141) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-15.227) r2: (test=0.124) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-15.750) r2: (test=0.153) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-15.109) r2: (test=0.138) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-16.164) r2: (test=0.139) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-13.972) r2: (test=0.262) total time=   0.4s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-14.244) r2: (test=0.234) total time=   0.3s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-14.564) r2: (test=0.276) total time=   0.4s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-14.054) r2: (test=0.254) total time=   0.4s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-15.025) r2: (test=0.256) total time=   0.4s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-11.289) r2: (test=0.518) total time=   0.9s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-11.861) r2: (test=0.469) total time=   0.8s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-11.736) r2: (test=0.530) total time=   1.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-11.489) r2: (test=0.502) total time=   2.9s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-12.259) r2: (test=0.505) total time=   0.9s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-15.017) r2: (test=0.147) total time=   0.4s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-15.183) r2: (test=0.129) total time=   0.4s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-15.698) r2: (test=0.159) total time=   0.4s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-15.093) r2: (test=0.140) total time=   0.5s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-16.121) r2: (test=0.143) total time=   0.4s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-13.874) r2: (test=0.272) total time=   0.8s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-14.200) r2: (test=0.238) total time=   0.8s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-14.440) r2: (test=0.288) total time=   0.8s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-14.023) r2: (test=0.257) total time=   0.8s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-14.957) r2: (test=0.263) total time=   0.9s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-11.170) r2: (test=0.528) total time=   2.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-11.802) r2: (test=0.474) total time=   3.8s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-11.554) r2: (test=0.544) total time=   1.9s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-11.434) r2: (test=0.506) total time=   2.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-12.232) r2: (test=0.507) total time=   2.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-9.742) r2: (test=0.641) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-10.393) r2: (test=0.592) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-10.574) r2: (test=0.618) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-10.478) r2: (test=0.585) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-11.017) r2: (test=0.600) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-7.206) r2: (test=0.804) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-8.073) r2: (test=0.754) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-7.814) r2: (test=0.792) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-8.121) r2: (test=0.751) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-8.864) r2: (test=0.741) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-5.068) r2: (test=0.903) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-5.952) r2: (test=0.866) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-5.599) r2: (test=0.893) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-6.070) r2: (test=0.861) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-7.056) r2: (test=0.836) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-8.346) r2: (test=0.737) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-9.296) r2: (test=0.674) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-8.681) r2: (test=0.743) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-8.608) r2: (test=0.720) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-9.344) r2: (test=0.712) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-5.892) r2: (test=0.869) total time=   0.4s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-6.871) r2: (test=0.822) total time=   0.8s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-6.127) r2: (test=0.872) total time=   1.3s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-6.253) r2: (test=0.852) total time=   0.9s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-7.103) r2: (test=0.834) total time=   0.4s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-4.767) r2: (test=0.914) total time=   0.9s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-5.312) r2: (test=0.893) total time=   0.9s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-4.976) r2: (test=0.915) total time=   0.9s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-5.064) r2: (test=0.903) total time=   0.8s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-6.254) r2: (test=0.871) total time=   0.9s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-8.363) r2: (test=0.735) total time=   0.5s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-9.188) r2: (test=0.681) total time=   0.4s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-8.467) r2: (test=0.755) total time=   0.4s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-8.613) r2: (test=0.720) total time=   0.4s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-9.320) r2: (test=0.714) total time=   0.5s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-6.008) r2: (test=0.863) total time=   0.9s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-6.924) r2: (test=0.819) total time=   0.9s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-5.858) r2: (test=0.883) total time=   0.9s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-6.047) r2: (test=0.862) total time=   3.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-6.876) r2: (test=0.844) total time=   0.9s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-5.219) r2: (test=0.897) total time=   2.4s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-5.693) r2: (test=0.878) total time=   2.3s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-4.946) r2: (test=0.916) total time=   2.5s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-5.082) r2: (test=0.902) total time=   3.6s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-6.064) r2: (test=0.879) total time=   3.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-4.472) r2: (test=0.924) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-5.426) r2: (test=0.889) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-4.961) r2: (test=0.916) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-5.240) r2: (test=0.896) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-6.459) r2: (test=0.863) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-4.046) r2: (test=0.938) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-5.120) r2: (test=0.901) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-4.643) r2: (test=0.926) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-4.804) r2: (test=0.913) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-6.128) r2: (test=0.876) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-3.690) r2: (test=0.949) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-4.865) r2: (test=0.911) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-4.451) r2: (test=0.932) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-4.497) r2: (test=0.924) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-5.814) r2: (test=0.889) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-4.616) r2: (test=0.919) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-4.996) r2: (test=0.906) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-4.700) r2: (test=0.925) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-4.803) r2: (test=0.913) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-6.119) r2: (test=0.877) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-4.502) r2: (test=0.923) total time=   0.3s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-4.879) r2: (test=0.910) total time=   0.3s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-4.691) r2: (test=0.925) total time=   0.3s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-4.603) r2: (test=0.920) total time=   0.3s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-6.001) r2: (test=0.881) total time=   0.3s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-4.492) r2: (test=0.924) total time=   0.4s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-4.805) r2: (test=0.913) total time=   0.5s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-4.704) r2: (test=0.924) total time=   0.4s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-4.584) r2: (test=0.921) total time=   0.5s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-5.934) r2: (test=0.884) total time=   0.5s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-5.086) r2: (test=0.902) total time=   0.4s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-5.705) r2: (test=0.877) total time=   0.4s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-4.917) r2: (test=0.917) total time=   0.4s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-5.133) r2: (test=0.901) total time=   0.7s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-5.954) r2: (test=0.883) total time=   1.5s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-5.077) r2: (test=0.902) total time=   0.9s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-5.699) r2: (test=0.877) total time=   0.5s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-4.910) r2: (test=0.918) total time=   0.5s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-5.128) r2: (test=0.901) total time=   0.5s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-5.950) r2: (test=0.883) total time=   0.5s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-5.077) r2: (test=0.902) total time=   0.5s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-5.699) r2: (test=0.877) total time=   0.5s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-4.910) r2: (test=0.918) total time=   0.5s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-5.128) r2: (test=0.901) total time=   0.5s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-5.950) r2: (test=0.883) total time=   0.5s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-4.600) r2: (test=0.920) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-5.734) r2: (test=0.876) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-5.733) r2: (test=0.888) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-5.279) r2: (test=0.895) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-7.512) r2: (test=0.814) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-4.463) r2: (test=0.925) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-5.551) r2: (test=0.884) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-5.734) r2: (test=0.888) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-5.177) r2: (test=0.899) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-7.635) r2: (test=0.808) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-4.493) r2: (test=0.924) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-5.629) r2: (test=0.880) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-5.780) r2: (test=0.886) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-5.208) r2: (test=0.898) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-7.619) r2: (test=0.809) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-5.434) r2: (test=0.888) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-7.872) r2: (test=0.766) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-6.315) r2: (test=0.864) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-6.398) r2: (test=0.845) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-7.183) r2: (test=0.830) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-5.434) r2: (test=0.888) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-7.872) r2: (test=0.766) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-6.315) r2: (test=0.864) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-6.398) r2: (test=0.845) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-7.183) r2: (test=0.830) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-5.434) r2: (test=0.888) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-7.872) r2: (test=0.766) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-6.315) r2: (test=0.864) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-6.398) r2: (test=0.845) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-7.183) r2: (test=0.830) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-5.865) r2: (test=0.870) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-7.048) r2: (test=0.812) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-5.889) r2: (test=0.882) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-7.067) r2: (test=0.811) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-8.088) r2: (test=0.784) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-5.865) r2: (test=0.870) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-7.048) r2: (test=0.812) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-5.889) r2: (test=0.882) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-7.067) r2: (test=0.811) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-8.088) r2: (test=0.784) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-5.865) r2: (test=0.870) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-7.048) r2: (test=0.812) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-5.889) r2: (test=0.882) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-7.067) r2: (test=0.811) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-8.088) r2: (test=0.784) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-15.323) r2: (test=0.112) total time=   0.0s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-15.412) r2: (test=0.103) total time=   0.0s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-16.069) r2: (test=0.119) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-15.383) r2: (test=0.106) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-16.454) r2: (test=0.108) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-14.442) r2: (test=0.211) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-14.597) r2: (test=0.195) total time=   0.2s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-15.144) r2: (test=0.217) total time=   0.2s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-14.577) r2: (test=0.198) total time=   0.4s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-15.529) r2: (test=0.205) total time=   0.5s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-12.247) r2: (test=0.433) total time=   0.6s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-12.620) r2: (test=0.398) total time=   1.0s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-12.992) r2: (test=0.424) total time=   0.2s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-12.589) r2: (test=0.402) total time=   0.2s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-13.347) r2: (test=0.413) total time=   0.2s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-15.070) r2: (test=0.141) total time=   0.2s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-15.227) r2: (test=0.124) total time=   0.2s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-15.750) r2: (test=0.153) total time=   0.2s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-15.109) r2: (test=0.138) total time=   0.2s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-16.164) r2: (test=0.139) total time=   0.2s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-13.972) r2: (test=0.262) total time=   0.4s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-14.244) r2: (test=0.234) total time=   0.3s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-14.564) r2: (test=0.276) total time=   0.4s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-14.054) r2: (test=0.254) total time=   0.4s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-15.025) r2: (test=0.256) total time=   0.4s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-11.291) r2: (test=0.518) total time=   0.9s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-11.861) r2: (test=0.469) total time=   0.8s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-11.736) r2: (test=0.530) total time=   0.9s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-11.489) r2: (test=0.502) total time=   0.9s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-12.259) r2: (test=0.505) total time=   0.9s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-15.017) r2: (test=0.147) total time=   0.5s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-15.183) r2: (test=0.129) total time=   0.4s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-15.698) r2: (test=0.159) total time=   0.4s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-15.093) r2: (test=0.140) total time=   0.4s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-16.121) r2: (test=0.143) total time=   0.6s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-13.874) r2: (test=0.272) total time=   2.7s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-14.199) r2: (test=0.238) total time=   0.8s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-14.440) r2: (test=0.288) total time=   0.8s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-14.023) r2: (test=0.257) total time=   0.8s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-14.958) r2: (test=0.263) total time=   0.9s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-11.170) r2: (test=0.528) total time=   2.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-11.802) r2: (test=0.474) total time=   1.9s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-11.554) r2: (test=0.544) total time=   2.0s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-11.434) r2: (test=0.506) total time=   3.9s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-12.232) r2: (test=0.507) total time=   2.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-9.742) r2: (test=0.641) total time=   0.0s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-10.393) r2: (test=0.592) total time=   0.0s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-10.574) r2: (test=0.618) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-10.478) r2: (test=0.585) total time=   0.0s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-11.017) r2: (test=0.600) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-7.206) r2: (test=0.804) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-8.073) r2: (test=0.754) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-7.814) r2: (test=0.792) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-8.121) r2: (test=0.751) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-8.864) r2: (test=0.741) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-5.068) r2: (test=0.903) total time=   0.2s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-5.952) r2: (test=0.866) total time=   0.2s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-5.601) r2: (test=0.893) total time=   0.2s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-6.070) r2: (test=0.861) total time=   0.2s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-7.056) r2: (test=0.836) total time=   0.2s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-8.346) r2: (test=0.737) total time=   0.2s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-9.296) r2: (test=0.674) total time=   0.2s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-8.690) r2: (test=0.742) total time=   0.2s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-8.606) r2: (test=0.720) total time=   0.2s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-9.345) r2: (test=0.712) total time=   0.2s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-5.881) r2: (test=0.869) total time=   0.4s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-6.869) r2: (test=0.822) total time=   0.3s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-6.143) r2: (test=0.871) total time=   0.4s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-6.286) r2: (test=0.851) total time=   0.4s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-7.110) r2: (test=0.833) total time=   0.4s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-4.765) r2: (test=0.914) total time=   0.9s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-5.347) r2: (test=0.892) total time=   0.9s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-4.983) r2: (test=0.915) total time=   1.8s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-5.048) r2: (test=0.904) total time=   1.8s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-6.231) r2: (test=0.872) total time=   0.9s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-8.368) r2: (test=0.735) total time=   0.4s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-9.198) r2: (test=0.680) total time=   0.4s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-8.474) r2: (test=0.755) total time=   0.4s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-8.615) r2: (test=0.720) total time=   0.4s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-9.324) r2: (test=0.713) total time=   0.5s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-6.032) r2: (test=0.862) total time=   0.9s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-6.941) r2: (test=0.818) total time=   0.9s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-5.859) r2: (test=0.883) total time=   1.0s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-6.050) r2: (test=0.862) total time=   0.9s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-6.890) r2: (test=0.844) total time=   1.0s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-5.174) r2: (test=0.899) total time=   3.7s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-5.673) r2: (test=0.878) total time=   2.9s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-4.888) r2: (test=0.918) total time=   2.4s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-5.068) r2: (test=0.903) total time=   2.3s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-6.051) r2: (test=0.879) total time=   2.4s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-4.472) r2: (test=0.924) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-5.426) r2: (test=0.889) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-4.961) r2: (test=0.916) total time=   0.0s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-5.240) r2: (test=0.896) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-6.459) r2: (test=0.863) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-4.040) r2: (test=0.938) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-5.101) r2: (test=0.902) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-4.665) r2: (test=0.926) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-4.804) r2: (test=0.913) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-6.128) r2: (test=0.876) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-3.659) r2: (test=0.949) total time=   0.3s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-4.779) r2: (test=0.914) total time=   1.0s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-4.398) r2: (test=0.934) total time=   0.5s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-4.518) r2: (test=0.923) total time=   1.0s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-5.834) r2: (test=0.888) total time=   0.2s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-4.614) r2: (test=0.919) total time=   0.2s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-5.007) r2: (test=0.905) total time=   0.2s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-4.683) r2: (test=0.925) total time=   0.2s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-4.723) r2: (test=0.916) total time=   0.2s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-6.112) r2: (test=0.877) total time=   0.2s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-4.505) r2: (test=0.923) total time=   0.2s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-4.867) r2: (test=0.911) total time=   0.3s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-4.652) r2: (test=0.926) total time=   0.3s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-4.559) r2: (test=0.922) total time=   0.3s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-6.011) r2: (test=0.881) total time=   0.3s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-4.505) r2: (test=0.923) total time=   0.3s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-4.867) r2: (test=0.911) total time=   0.3s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-4.652) r2: (test=0.926) total time=   0.3s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-4.559) r2: (test=0.922) total time=   0.3s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-6.011) r2: (test=0.881) total time=   0.3s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-5.138) r2: (test=0.900) total time=   0.3s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-5.764) r2: (test=0.874) total time=   0.3s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-4.838) r2: (test=0.920) total time=   0.3s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-5.095) r2: (test=0.902) total time=   0.3s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-5.976) r2: (test=0.882) total time=   0.4s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-5.138) r2: (test=0.900) total time=   0.4s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-5.764) r2: (test=0.874) total time=   0.3s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-4.838) r2: (test=0.920) total time=   0.4s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-5.095) r2: (test=0.902) total time=   0.4s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-5.976) r2: (test=0.882) total time=   0.3s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-5.138) r2: (test=0.900) total time=   0.4s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-5.764) r2: (test=0.874) total time=   0.4s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-4.838) r2: (test=0.920) total time=   0.4s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-5.095) r2: (test=0.902) total time=   0.4s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-5.976) r2: (test=0.882) total time=   0.4s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-4.654) r2: (test=0.918) total time=   0.0s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-5.749) r2: (test=0.875) total time=   0.0s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-5.677) r2: (test=0.890) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-5.279) r2: (test=0.895) total time=   0.0s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-7.427) r2: (test=0.818) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-4.588) r2: (test=0.920) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-5.743) r2: (test=0.875) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-5.844) r2: (test=0.883) total time=   0.2s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-5.212) r2: (test=0.897) total time=   0.2s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-7.424) r2: (test=0.818) total time=   0.4s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-4.588) r2: (test=0.920) total time=   0.8s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-5.743) r2: (test=0.875) total time=   0.3s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-5.836) r2: (test=0.884) total time=   0.6s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-5.212) r2: (test=0.897) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-7.432) r2: (test=0.818) total time=   0.2s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-5.434) r2: (test=0.888) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-7.506) r2: (test=0.787) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-6.337) r2: (test=0.863) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-6.315) r2: (test=0.849) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-7.336) r2: (test=0.823) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-5.434) r2: (test=0.888) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-7.506) r2: (test=0.787) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-6.337) r2: (test=0.863) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-6.315) r2: (test=0.849) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-7.336) r2: (test=0.823) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-5.434) r2: (test=0.888) total time=   0.2s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-7.506) r2: (test=0.787) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-6.337) r2: (test=0.863) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-6.315) r2: (test=0.849) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-7.336) r2: (test=0.823) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-5.798) r2: (test=0.873) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-6.874) r2: (test=0.822) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-6.251) r2: (test=0.867) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-7.025) r2: (test=0.814) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-8.181) r2: (test=0.779) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-5.798) r2: (test=0.873) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-6.874) r2: (test=0.822) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-6.251) r2: (test=0.867) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-7.025) r2: (test=0.814) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-8.181) r2: (test=0.779) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-5.798) r2: (test=0.873) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-6.874) r2: (test=0.822) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-6.251) r2: (test=0.867) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-7.025) r2: (test=0.814) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-8.181) r2: (test=0.779) total time=   0.1s
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=2021, ...),
#              param_grid={'gamma': [0.01, 0.1],
#                          'learning_rate': [0.001, 0.01, 0.1, 1],
#                          'max_depth': [3, 6, 9],
#                          'n_estimators': [100, 200, 500]},
#              refit='r2', scoring=['r2', 'neg_root_mean_squared_error'],
#              verbose=4)

# %%
print(GS.best_estimator_)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0.1, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=500, n_jobs=None,
#              num_parallel_tree=None, random_state=2021, ...)

# %%
print(GS.best_params_)
# Out:
# {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}

# %%
print(GS.best_score_) # score according to the metric we passed in refit
# Out:
# 0.921563136246513

# %%
df = pd.DataFrame(GS.cv_results_)
df = df.sort_values("rank_test_r2")
df.to_csv("cv_results.csv", index = False)

# %%
path2= "/content/cv_results.csv"
df = pd.read_csv(path2)
df.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_gamma  \
# 0       0.628336      0.347565         0.005486        0.001759         0.10
# 1       0.199266      0.015858         0.003373        0.000104         0.01
# 2       0.455797      0.019025         0.005552        0.002897         0.01
# 3       0.260096      0.012082         0.003359        0.000054         0.10
# 4       0.317589      0.013768         0.003539        0.000060         0.10
#
#    param_learning_rate  param_max_depth  param_n_estimators  \
# 0                  0.1                3                 500
# 1                  0.1                3                 500
# 2                  0.1                6                 500
# 3                  0.1                6                 200
# 4                  0.1                6                 500
#
#                                               params  split0_test_r2  ...  \
# 0  {'gamma': 0.1, 'learning_rate': 0.1, 'max_dept...        0.949352  ...
# 1  {'gamma': 0.01, 'learning_rate': 0.1, 'max_dep...        0.948504  ...
# 2  {'gamma': 0.01, 'learning_rate': 0.1, 'max_dep...        0.923653  ...
# 3  {'gamma': 0.1, 'learning_rate': 0.1, 'max_dept...        0.923217  ...
# 4  {'gamma': 0.1, 'learning_rate': 0.1, 'max_dept...        0.923216  ...
#
#    std_test_r2  rank_test_r2  split0_test_neg_root_mean_squared_error  \
# 0     0.020627             1                                -3.659054
# 1     0.020255             2                                -3.689564
# 2     0.015164             3                                -4.492463
# 3     0.016636             4                                -4.505282
# 4     0.016636             5                                -4.505291
#
#    split1_test_neg_root_mean_squared_error  \
# 0                                -4.778983
# 1                                -4.865246
# 2                                -4.805026
# 3                                -4.867040
# 4                                -4.867058
#
#    split2_test_neg_root_mean_squared_error  \
# 0                                -4.398091
# 1                                -4.450950
# 2                                -4.703881
# 3                                -4.651678
# 4                                -4.651708
#
#    split3_test_neg_root_mean_squared_error  \
# 0                                -4.518201
# 1                                -4.497008
# 2                                -4.584079
# 3                                -4.559368
# 4                                -4.559366
#
#    split4_test_neg_root_mean_squared_error  \
# 0                                -5.833515
# 1                                -5.813776
# 2                                -5.934445
# 3                                -6.010741
# 4                                -6.010733
#
#    mean_test_neg_root_mean_squared_error  \
# 0                              -4.637569
# 1                              -4.663309
# 2                              -4.903979
# 3                              -4.918822
# 4                              -4.918831
#
#    std_test_neg_root_mean_squared_error  rank_test_neg_root_mean_squared_error
# 0                              0.704184                                      1
# 1                              0.690693                                      2
# 2                              0.525998                                      3
# 3                              0.559742                                      4
# 4                              0.559735                                      5
#
# [5 rows x 25 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['mean_fit_time'].plot(kind='hist', bins=20, title='mean_fit_time')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['std_fit_time'].plot(kind='hist', bins=20, title='std_fit_time')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['mean_score_time'].plot(kind='hist', bins=20, title='mean_score_time')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['std_score_time'].plot(kind='hist', bins=20, title='std_score_time')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('params').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='mean_fit_time', y='std_fit_time', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='std_fit_time', y='mean_score_time', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='mean_score_time', y='std_score_time', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='std_score_time', y='param_gamma', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['mean_fit_time']
#   ys = series['param_gamma']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('mean_fit_time', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('params')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='params', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('mean_fit_time')
# _ = plt.ylabel('param_gamma')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['mean_fit_time']
#   ys = series['param_n_estimators']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('mean_fit_time', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('params')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='params', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('mean_fit_time')
# _ = plt.ylabel('param_n_estimators')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['mean_fit_time']
#   ys = series['split0_test_r2']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('mean_fit_time', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('params')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='params', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('mean_fit_time')
# _ = plt.ylabel('split0_test_r2')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['mean_fit_time']
#   ys = series['split1_test_r2']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_12.sort_values('mean_fit_time', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('params')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='params', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('mean_fit_time')
# _ = plt.ylabel('split1_test_r2')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_13['mean_fit_time'].plot(kind='line', figsize=(8, 4), title='mean_fit_time')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['std_fit_time'].plot(kind='line', figsize=(8, 4), title='std_fit_time')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['mean_score_time'].plot(kind='line', figsize=(8, 4), title='mean_score_time')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16['std_score_time'].plot(kind='line', figsize=(8, 4), title='std_score_time')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_17['params'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_17, x='mean_fit_time', y='params', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_18['params'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_18, x='std_fit_time', y='params', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_19['params'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_19, x='mean_score_time', y='params', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_20['params'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_20, x='std_score_time', y='params', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
